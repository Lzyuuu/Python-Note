# %% [markdown]
# # API

# %%
import requests

# 执行API调用并存储响应
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r = requests.get(url)
print("Status code:", r.status_code)

# 将API响应存储到变量中
response_dict = r.json()
print("Total Repositories:", response_dict['total_count'])

# 处理结果，打印键
print(response_dict.keys())

# 探索有关仓库的信息
repo_dicts = response_dict['items']
print("Repositories returned:", len(repo_dicts))

# 研究第一个仓库
repo_dict = repo_dicts[0]
print('\nKeys:', len(repo_dict))

print("\nSelected information about first repository:")
print('Name:', repo_dict['name'])
print('Owner:', repo_dict['owner']['login'])
print('Stars:', repo_dict['stargazers_count'])
print('Repository:', repo_dict['html_url'])
print('Created:', repo_dict['created_at'])
print('Updated:', repo_dict['updated_at'])
print('Description:', repo_dict['description'])
# Out:
# Status code: 200
# Total Repositories: 2588014
# dict_keys(['total_count', 'incomplete_results', 'items'])
# Repositories returned: 30
#
# Keys: 72
#
# Selected information about first repository:
# Name: awesome-python
# Owner: vinta
# Stars: 49116
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2018-04-29T09:17:36Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources

# %%
import requests

# 获取url
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r = requests.get(url)
print('Status code:', r.status_code)

# 将API响应存储到可被操作的变量中
response_dict = r.json()
print("Total repositories:", response_dict['total_count'])
print(response_dict.keys())

# 读取仓库信息列表
repo_dicts = response_dict['items']
print('Repositories returned:', len(repo_dicts))

# 打印每一个仓库的信息
print('\nSecleted information about each repository:')
for repo_dict in repo_dicts:
    print('\nName:', repo_dict['name'])
    print('Owner:', repo_dict['owner']['login'])
    print('Stars:', repo_dict['stargazers_count'])
    print('Repository:', repo_dict['html_url'])
    print('Created:', repo_dict['created_at'])
    print('Updated:', repo_dict['updated_at'])
    print('Description:', repo_dict['description'])
# Out:
# Status code: 200
# Total repositories: 2588033
# dict_keys(['total_count', 'incomplete_results', 'items'])
# Repositories returned: 30
#
# Secleted information about each repository:
#
# Name: awesome-python
# Owner: vinta
# Stars: 49116
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2018-04-29T09:17:36Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources
#
# Name: youtube-dl
# Owner: rg3
# Stars: 36361
# Repository: https://github.com/rg3/youtube-dl
# Created: 2010-10-31T14:35:07Z
# Updated: 2018-04-29T05:41:54Z
# Description: Command-line program to download videos from YouTube.com and other video sites
#
# Name: public-apis
# Owner: toddmotto
# Stars: 36047
# Repository: https://github.com/toddmotto/public-apis
# Created: 2016-03-20T23:49:42Z
# Updated: 2018-04-29T07:39:08Z
# Description: A collective list of public JSON APIs for use in web development.
#
# Name: flask
# Owner: pallets
# Stars: 35232
# Repository: https://github.com/pallets/flask
# Created: 2010-04-06T11:11:59Z
# Updated: 2018-04-29T09:02:48Z
# Description: The Python micro framework for building web applications.
#
# Name: httpie
# Owner: jakubroztocil
# Stars: 35072
# Repository: https://github.com/jakubroztocil/httpie
# Created: 2012-02-25T12:39:13Z
# Updated: 2018-04-29T08:59:36Z
# Description: Modern command line HTTP client – user-friendly curl alternative with intuitive UI, JSON support, syntax highlighting, wget-like downloads, extensions, etc.  https://httpie.org
#
# Name: thefuck
# Owner: nvbn
# Stars: 35022
# Repository: https://github.com/nvbn/thefuck
# Created: 2015-04-08T15:08:04Z
# Updated: 2018-04-29T08:14:19Z
# Description: Magnificent app which corrects your previous console command.
#
# Name: models
# Owner: tensorflow
# Stars: 33984
# Repository: https://github.com/tensorflow/models
# Created: 2016-02-05T01:15:20Z
# Updated: 2018-04-29T08:32:00Z
# Description: Models and examples built with TensorFlow
#
# Name: django
# Owner: django
# Stars: 33502
# Repository: https://github.com/django/django
# Created: 2012-04-28T02:47:18Z
# Updated: 2018-04-29T06:14:07Z
# Description: The Web framework for perfectionists with deadlines.
#
# Name: awesome-machine-learning
# Owner: josephmisiti
# Stars: 32368
# Repository: https://github.com/josephmisiti/awesome-machine-learning
# Created: 2014-07-15T19:11:19Z
# Updated: 2018-04-29T08:25:35Z
# Description: A curated list of awesome Machine Learning frameworks, libraries and software.
#
# Name: requests
# Owner: requests
# Stars: 32038
# Repository: https://github.com/requests/requests
# Created: 2011-02-13T18:38:17Z
# Updated: 2018-04-29T09:40:01Z
# Description: Python HTTP Requests for Humans™ ✨🍰✨
#
# Name: ansible
# Owner: ansible
# Stars: 29932
# Repository: https://github.com/ansible/ansible
# Created: 2012-03-06T14:58:02Z
# Updated: 2018-04-29T03:56:18Z
# Description: Ansible is a radically simple IT automation platform that makes your applications and systems easier to deploy. Avoid writing scripts or custom code to deploy and update your applications — automate in a language that approaches plain English, using SSH, with no agents to install on remote systems. https://docs.ansible.com/ansible/
#
# Name: keras
# Owner: keras-team
# Stars: 28819
# Repository: https://github.com/keras-team/keras
# Created: 2015-03-28T00:35:42Z
# Updated: 2018-04-29T08:54:33Z
# Description: Deep Learning for humans
#
# Name: scikit-learn
# Owner: scikit-learn
# Stars: 27716
# Repository: https://github.com/scikit-learn/scikit-learn
# Created: 2010-08-17T09:43:38Z
# Updated: 2018-04-29T05:06:06Z
# Description: scikit-learn: machine learning in Python
#
# Name: scrapy
# Owner: scrapy
# Stars: 26980
# Repository: https://github.com/scrapy/scrapy
# Created: 2010-02-22T02:01:14Z
# Updated: 2018-04-29T07:55:03Z
# Description: Scrapy, a fast high-level web crawling & scraping framework for Python.
#
# Name: system-design-primer
# Owner: donnemartin
# Stars: 25669
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2018-04-29T08:00:40Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
#
# Name: shadowsocks
# Owner: shadowsocks
# Stars: 24698
# Repository: https://github.com/shadowsocks/shadowsocks
# Created: 2012-04-20T13:10:49Z
# Updated: 2018-04-29T08:53:21Z
# Description: None
#
# Name: big-list-of-naughty-strings
# Owner: minimaxir
# Stars: 23709
# Repository: https://github.com/minimaxir/big-list-of-naughty-strings
# Created: 2015-08-08T20:57:20Z
# Updated: 2018-04-29T09:32:12Z
# Description: The Big List of Naughty Strings is a list of strings which have a high probability of causing issues when used as user-input data.
#
# Name: XX-Net
# Owner: XX-net
# Stars: 22507
# Repository: https://github.com/XX-net/XX-Net
# Created: 2015-01-15T09:35:51Z
# Updated: 2018-04-29T08:52:18Z
# Description: a web proxy tool
#
# Name: certbot
# Owner: certbot
# Stars: 21987
# Repository: https://github.com/certbot/certbot
# Created: 2014-11-12T02:52:20Z
# Updated: 2018-04-29T09:06:26Z
# Description: Certbot is EFF's tool to obtain certs from Let's Encrypt and (optionally) auto-enable HTTPS on your server.  It can also act as a client for any other CA that uses the ACME protocol.
#
# Name: you-get
# Owner: soimort
# Stars: 18437
# Repository: https://github.com/soimort/you-get
# Created: 2012-08-20T15:53:36Z
# Updated: 2018-04-29T09:15:12Z
# Description: :arrow_double_down: Dumb downloader that scrapes the web
#
# Name: CppCoreGuidelines
# Owner: isocpp
# Stars: 18188
# Repository: https://github.com/isocpp/CppCoreGuidelines
# Created: 2015-08-19T20:22:52Z
# Updated: 2018-04-29T09:27:48Z
# Description: The C++ Core Guidelines are a set of tried-and-true guidelines, rules, and best practices about coding in C++
#
# Name: linux-insides
# Owner: 0xAX
# Stars: 17457
# Repository: https://github.com/0xAX/linux-insides
# Created: 2015-01-03T18:44:57Z
# Updated: 2018-04-29T04:31:23Z
# Description: A little bit about a linux kernel
#
# Name: cpython
# Owner: python
# Stars: 17416
# Repository: https://github.com/python/cpython
# Created: 2017-02-10T19:23:51Z
# Updated: 2018-04-29T09:40:03Z
# Description: The Python programming language
#
# Name: Deep-Learning-Papers-Reading-Roadmap
# Owner: floodsung
# Stars: 16972
# Repository: https://github.com/floodsung/Deep-Learning-Papers-Reading-Roadmap
# Created: 2016-10-14T11:49:48Z
# Updated: 2018-04-29T08:56:51Z
# Description: Deep Learning papers reading roadmap for anyone who are eager to learn this amazing tech!
#
# Name: tldr
# Owner: tldr-pages
# Stars: 16971
# Repository: https://github.com/tldr-pages/tldr
# Created: 2013-12-08T07:34:43Z
# Updated: 2018-04-29T02:50:52Z
# Description: :books: Simplified and community-driven man pages
#
# Name: sentry
# Owner: getsentry
# Stars: 16446
# Repository: https://github.com/getsentry/sentry
# Created: 2010-08-30T22:06:41Z
# Updated: 2018-04-29T07:36:44Z
# Description: Sentry is cross-platform application monitoring, with a focus on error reporting.
#
# Name: YouCompleteMe
# Owner: Valloric
# Stars: 16337
# Repository: https://github.com/Valloric/YouCompleteMe
# Created: 2012-04-16T03:12:14Z
# Updated: 2018-04-29T09:13:08Z
# Description: A code-completion engine for Vim
#
# Name: tornado
# Owner: tornadoweb
# Stars: 15650
# Repository: https://github.com/tornadoweb/tornado
# Created: 2009-09-09T04:55:16Z
# Updated: 2018-04-29T03:50:47Z
# Description: Tornado is a Python web framework and asynchronous networking library, originally developed at FriendFeed.
#
# Name: python-patterns
# Owner: faif
# Stars: 15178
# Repository: https://github.com/faif/python-patterns
# Created: 2012-06-06T21:02:35Z
# Updated: 2018-04-29T08:32:13Z
# Description: A collection of design patterns/idioms in Python
#
# Name: reddit
# Owner: reddit-archive
# Stars: 14459
# Repository: https://github.com/reddit-archive/reddit
# Created: 2008-06-18T23:30:53Z
# Updated: 2018-04-29T05:30:48Z
# Description: historical code from reddit.com

# %%
import requests
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r = requests.get(url)
print("Status code:", r.status_code)

response_dict = r.json()
print("Total repositories:", response_dict['total_count'])

repo_dicts = response_dict['items']
print("Return repositories:", len(repo_dicts))

# 创建条形图的参数列表，名字和星星数
names, stars = [], []
for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])
    
# 可视化
my_style = LS('#333366', base_style=LCS)

my_config = pygal.Config()
my_config.x_label_rotation = 45
my_config.show_legend = False
my_config.title_font_size = 24
my_config.label_font_size = 14
my_config.major_label_font_size = 18
my_config.truncate_label = 15
my_config.show_y_guides = False
my_config.width = 1000

chart = pygal.Bar(my_config, style=my_style)
chart.title = 'Most-Starred Python Projects on GitHub'
chart.x_labels = names

chart.add('', stars)
chart.render_to_file('python_repo.svg')
# Out:
# Status code: 200
# Total repositories: 2588100
# Return repositories: 30

# %%
import requests
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r = requests.get(url)
print("Status code:", r.status_code)

response_dict = r.json()
print("Total repositories:", response_dict['total_count'])

repo_dicts = response_dict['items']
print("Return repositories:", len(repo_dicts))

# 创建条形图的参数列表，名字和星星数
names, plot_dicts = [], []
for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    
    plot_dict = {
        'value': repo_dict['stargazers_count'],
        'xlink': repo_dict['html_url'],
    }
    plot_dicts.append(plot_dict)
    
# 可视化
my_style = LS('#333366', base_style=LCS)

my_config = pygal.Config()
my_config.x_label_rotation = 45
my_config.show_legend = False
my_config.title_font_size = 24
my_config.label_font_size = 14
my_config.major_label_font_size = 18
my_config.truncate_label = 15
my_config.show_y_guides = False
my_config.width = 1000

chart = pygal.Bar(my_config, style=my_style)
chart.title = 'Most-Starred Python Projects on GitHub'
chart.x_labels = names

chart.add('', plot_dicts)
chart.render_to_file('python_repos.svg')
# Out:
# Status code: 200
# Total repositories: 2588118
# Return repositories: 30

# %% [markdown]
# ## Hacker News API

# %%
import requests
from operator import itemgetter

# 执行API调用并储存响应
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print("Status code:", r.status_code)

# 处理有关每篇文章的信息
submission_ids = r.json()
submission_dicts = []
for submission_id in submission_ids[:30]:
    # 对于每篇文章，都执行一个API调用
    url = 'https://hacker-news.firebaseio.com/v0/item/' + str(submission_id) + '.json'
    submission_r = requests.get(url)
    print(submission_r.status_code)
    response_dict = submission_r.json()
    
    submission_dict = {
        'title': response_dict['title'],
        'link': 'http://news.ycombinator.com/item?id=' + str(submission_id),
        'comments': response_dict.get('descendants', 0),
    }
    submission_dicts.append(submission_dict)
    
submission_dicts = sorted(submission_dicts, key=itemgetter('comments'), reverse=True)

for submission_dict in submission_dicts:
    print('\nTitle:', submission_dict['title'])
    print("Discussion link:", submission_dict['link'])
    print('Comments:', submission_dict['comments'])
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1121176a0>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/envs/python/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda3/envs/python/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='hacker-news.firebaseio.com', port=443): Max retries exceeded with url: /v0/topstories.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1121176a0>: Failed to establish a new connection: [Errno 60] Operation timed out',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-31-e763452807ee> in <module>()
#       4 # 执行API调用并储存响应
#       5 url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
# ----> 6 r = requests.get(url)
#       7 print("Status code:", r.status_code)
#       8
#
# /anaconda3/envs/python/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/envs/python/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/envs/python/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/envs/python/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/envs/python/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='hacker-news.firebaseio.com', port=443): Max retries exceeded with url: /v0/topstories.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1121176a0>: Failed to establish a new connection: [Errno 60] Operation timed out',))
